# %% [markdown]
# # Тут есть текст, который в последствии стал заголовком
# Работу выполняли:
#
#
# 1.   Дальчанин
# 2.   Булатов
#
# 1.   Павликов
#
#
# | Студент        | Количество падений в снег           | День рождения |
# | :-------------:|:-------------:| -----:|
# | Дальчанин |1 | ??? |
# | Булатов     | 14     |   23.02.2004 |
# | Павликов | 1      |    12.07.2004 |
#
# [Полезная информация](https://konvut.github.io/k50articles/)
#
# Какие - либо изменения
#
#
# ![big-data-artificial-intelligence-concept-260nw-1222950196 (2).jpg](data:image/jpeg;base64,...)
